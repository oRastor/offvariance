# %%
from modules.client import OffVarianceClient
from dotenv import dotenv_values

config = dotenv_values('../.env')

client = OffVarianceClient(config.get('OFF_VARIANCE_KEY'), data_path='../data')
games_df = client.get_unfinished_games()

# %%
games_df
# Out:
#           id           date_match  date_match_unix  team_1_id     team_1_name  \
# 0     135116  02.02.2022 21:00:00       1643828400      24070         Benfica
# 1     145988  02.02.2022 21:00:00       1643828400      48881     Bucaramanga
# 2     134785  02.02.2022 21:30:00       1643830200      23423         Smyrnis
# 3     130492  02.02.2022 21:45:00       1643831100      24260          Celtic
# 4     138378  02.02.2022 21:45:00       1643831100      26964        Barnsley
# ...      ...                  ...              ...        ...             ...
# 1128  122387  23.02.2022 02:00:00       1645574400     121917           Sevan
# 1129  122388  23.02.2022 02:00:00       1645574400      18907  Ararat Yerevan
# 1130  122389  23.02.2022 02:00:00       1645574400      18899       Alashkert
# 1131  123016  23.02.2022 02:00:00       1645574400      18901          Urartu
# 1132  133857  23.02.2022 16:00:00       1645624800      18900  Pyunik Yerevan
#
#       team_2_id     team_2_name  country_id country_name  league_id  ...  \
# 0         62198     Gil Vicente       779.0     Portugal        785  ...
# 1         48875       Petrolera      1787.0     Colombia       2213  ...
# 2         23408            PAOK       776.0       Greece        786  ...
# 3         24261         Rangers       782.0     Scotland        783  ...
# 4          6732         Cardiff       291.0      England        428  ...
# ...         ...             ...         ...          ...        ...  ...
# 1128      89920          FC Van       626.0      Armenia        631  ...
# 1129      18906            Noah       626.0      Armenia        631  ...
# 1130      18904  Ararat-Armenia       626.0      Armenia        631  ...
# 1131     121916        Noravank       626.0      Armenia        631  ...
# 1132     121915            BKMA       626.0      Armenia        631  ...
#
#      odds_open_win1  odds_open_draw odds_open_win2  odds_open_tm25  \
# 0             1.248            6.50         13.170           2.520
# 1               NaN             NaN            NaN             NaN
# 2             6.320            3.99          1.558           1.787
# 3             2.150            3.58          3.520           1.917
# 4             2.760            3.24          2.800           1.740
# ...             ...             ...            ...             ...
# 1128            NaN             NaN            NaN             NaN
# 1129            NaN             NaN            NaN             NaN
# 1130            NaN             NaN            NaN             NaN
# 1131            NaN             NaN            NaN             NaN
# 1132            NaN             NaN            NaN             NaN
#
#      odds_open_tb25  odds_close_win1  odds_close_draw  odds_close_win2  \
# 0             1.568            1.483             4.72            6.860
# 1               NaN              NaN              NaN              NaN
# 2             1.980            9.070             4.31            1.411
# 3             1.934            2.340             3.34            3.310
# 4             2.180            3.390             3.33            2.310
# ...             ...              ...              ...              ...
# 1128            NaN              NaN              NaN              NaN
# 1129            NaN              NaN              NaN              NaN
# 1130            NaN              NaN              NaN              NaN
# 1131            NaN              NaN              NaN              NaN
# 1132            NaN              NaN              NaN              NaN
#
#       odds_close_tm25  odds_close_tb25
# 0               2.270            1.684
# 1                 NaN              NaN
# 2               1.671            2.220
# 3               1.917            1.970
# 4               1.719            2.220
# ...               ...              ...
# 1128              NaN              NaN
# 1129              NaN              NaN
# 1130              NaN              NaN
# 1131              NaN              NaN
# 1132              NaN              NaN
#
# [1133 rows x 1397 columns]

# %%
games_df.columns.values
# Out:
# array(['id', 'date_match', 'date_match_unix', ..., 'odds_close_win2',
#        'odds_close_tm25', 'odds_close_tb25'], dtype=object)

# %%
games_df.columns[games_df.columns.str.contains("iv")].values
# Out:
# array(['team1_all_five_draw_xg90', 'team1_all_five_draw_xga90',
#        'team1_all_five_draw_xgxga', 'team1_all_five_draw_xg90xga90sum',
#        'team1_all_five_draw_minutes', 'team1_all_five_zero_xg90',
#        'team1_all_five_zero_xga90', 'team1_all_five_zero_xgxga',
#        'team1_all_five_zero_xg90xga90sum', 'team1_all_five_zero_minutes',
#        'team1_all_five_cxp_xg90', 'team1_all_five_cxp_xga90',
#        'team1_all_five_cxp_xgxga', 'team1_all_five_cxp_xg90xga90sum',
#        'team1_all_five_cxp_minutes', 'team1_all_five_cop_xg90',
#        'team1_all_five_cop_xga90', 'team1_all_five_cop_xgxga',
#        'team1_all_five_cop_xg90xga90sum', 'team1_all_five_cop_minutes',
#        'team1_all_five_com_xg90', 'team1_all_five_com_xga90',
#        'team1_all_five_com_xgxga', 'team1_all_five_com_xg90xga90sum',
#        'team1_all_five_com_minutes', 'team1_all_five_cxm_xg90',
#        'team1_all_five_cxm_xga90', 'team1_all_five_cxm_xgxga',
#        'team1_all_five_cxm_xg90xga90sum', 'team1_all_five_cxm_minutes',
#        'team1_home_five_draw_xg90', 'team1_home_five_draw_xga90',
#        'team1_home_five_draw_xgxga', 'team1_home_five_draw_xg90xga90sum',
#        'team1_home_five_draw_minutes', 'team1_home_five_zero_xg90',
#        'team1_home_five_zero_xga90', 'team1_home_five_zero_xgxga',
#        'team1_home_five_zero_xg90xga90sum',
#        'team1_home_five_zero_minutes', 'team1_home_five_cxp_xg90',
#        'team1_home_five_cxp_xga90', 'team1_home_five_cxp_xgxga',
#        'team1_home_five_cxp_xg90xga90sum', 'team1_home_five_cxp_minutes',
#        'team1_home_five_cop_xg90', 'team1_home_five_cop_xga90',
#        'team1_home_five_cop_xgxga', 'team1_home_five_cop_xg90xga90sum',
#        'team1_home_five_cop_minutes', 'team1_home_five_com_xg90',
#        'team1_home_five_com_xga90', 'team1_home_five_com_xgxga',
#        'team1_home_five_com_xg90xga90sum', 'team1_home_five_com_minutes',
#        'team1_home_five_cxm_xg90', 'team1_home_five_cxm_xga90',
#        'team1_home_five_cxm_xgxga', 'team1_home_five_cxm_xg90xga90sum',
#        'team1_home_five_cxm_minutes', 'team1_away_five_draw_xg90',
#        'team1_away_five_draw_xga90', 'team1_away_five_draw_xgxga',
#        'team1_away_five_draw_xg90xga90sum',
#        'team1_away_five_draw_minutes', 'team1_away_five_zero_xg90',
#        'team1_away_five_zero_xga90', 'team1_away_five_zero_xgxga',
#        'team1_away_five_zero_xg90xga90sum',
#        'team1_away_five_zero_minutes', 'team1_away_five_cxp_xg90',
#        'team1_away_five_cxp_xga90', 'team1_away_five_cxp_xgxga',
#        'team1_away_five_cxp_xg90xga90sum', 'team1_away_five_cxp_minutes',
#        'team1_away_five_cop_xg90', 'team1_away_five_cop_xga90',
#        'team1_away_five_cop_xgxga', 'team1_away_five_cop_xg90xga90sum',
#        'team1_away_five_cop_minutes', 'team1_away_five_com_xg90',
#        'team1_away_five_com_xga90', 'team1_away_five_com_xgxga',
#        'team1_away_five_com_xg90xga90sum', 'team1_away_five_com_minutes',
#        'team1_away_five_cxm_xg90', 'team1_away_five_cxm_xga90',
#        'team1_away_five_cxm_xgxga', 'team1_away_five_cxm_xg90xga90sum',
#        'team1_away_five_cxm_minutes', 'team2_all_five_draw_xg90',
#        'team2_all_five_draw_xga90', 'team2_all_five_draw_xgxga',
#        'team2_all_five_draw_xg90xga90sum', 'team2_all_five_draw_minutes',
#        'team2_all_five_zero_xg90', 'team2_all_five_zero_xga90',
#        'team2_all_five_zero_xgxga', 'team2_all_five_zero_xg90xga90sum',
#        'team2_all_five_zero_minutes', 'team2_all_five_cxp_xg90',
#        'team2_all_five_cxp_xga90', 'team2_all_five_cxp_xgxga',
#        'team2_all_five_cxp_xg90xga90sum', 'team2_all_five_cxp_minutes',
#        'team2_all_five_cop_xg90', 'team2_all_five_cop_xga90',
#        'team2_all_five_cop_xgxga', 'team2_all_five_cop_xg90xga90sum',
#        'team2_all_five_cop_minutes', 'team2_all_five_com_xg90',
#        'team2_all_five_com_xga90', 'team2_all_five_com_xgxga',
#        'team2_all_five_com_xg90xga90sum', 'team2_all_five_com_minutes',
#        'team2_all_five_cxm_xg90', 'team2_all_five_cxm_xga90',
#        'team2_all_five_cxm_xgxga', 'team2_all_five_cxm_xg90xga90sum',
#        'team2_all_five_cxm_minutes', 'team2_home_five_draw_xg90',
#        'team2_home_five_draw_xga90', 'team2_home_five_draw_xgxga',
#        'team2_home_five_draw_xg90xga90sum',
#        'team2_home_five_draw_minutes', 'team2_home_five_zero_xg90',
#        'team2_home_five_zero_xga90', 'team2_home_five_zero_xgxga',
#        'team2_home_five_zero_xg90xga90sum',
#        'team2_home_five_zero_minutes', 'team2_home_five_cxp_xg90',
#        'team2_home_five_cxp_xga90', 'team2_home_five_cxp_xgxga',
#        'team2_home_five_cxp_xg90xga90sum', 'team2_home_five_cxp_minutes',
#        'team2_home_five_cop_xg90', 'team2_home_five_cop_xga90',
#        'team2_home_five_cop_xgxga', 'team2_home_five_cop_xg90xga90sum',
#        'team2_home_five_cop_minutes', 'team2_home_five_com_xg90',
#        'team2_home_five_com_xga90', 'team2_home_five_com_xgxga',
#        'team2_home_five_com_xg90xga90sum', 'team2_home_five_com_minutes',
#        'team2_home_five_cxm_xg90', 'team2_home_five_cxm_xga90',
#        'team2_home_five_cxm_xgxga', 'team2_home_five_cxm_xg90xga90sum',
#        'team2_home_five_cxm_minutes', 'team2_away_five_draw_xg90',
#        'team2_away_five_draw_xga90', 'team2_away_five_draw_xgxga',
#        'team2_away_five_draw_xg90xga90sum',
#        'team2_away_five_draw_minutes', 'team2_away_five_zero_xg90',
#        'team2_away_five_zero_xga90', 'team2_away_five_zero_xgxga',
#        'team2_away_five_zero_xg90xga90sum',
#        'team2_away_five_zero_minutes', 'team2_away_five_cxp_xg90',
#        'team2_away_five_cxp_xga90', 'team2_away_five_cxp_xgxga',
#        'team2_away_five_cxp_xg90xga90sum', 'team2_away_five_cxp_minutes',
#        'team2_away_five_cop_xg90', 'team2_away_five_cop_xga90',
#        'team2_away_five_cop_xgxga', 'team2_away_five_cop_xg90xga90sum',
#        'team2_away_five_cop_minutes', 'team2_away_five_com_xg90',
#        'team2_away_five_com_xga90', 'team2_away_five_com_xgxga',
#        'team2_away_five_com_xg90xga90sum', 'team2_away_five_com_minutes',
#        'team2_away_five_cxm_xg90', 'team2_away_five_cxm_xga90',
#        'team2_away_five_cxm_xgxga', 'team2_away_five_cxm_xg90xga90sum',
#        'team2_away_five_cxm_minutes'], dtype=object)

# %%
client.get_unfinished_games()
# Out:
#           id           date_match  date_match_unix  team_1_id     team_1_name  \
# 0     135116  02.02.2022 21:00:00       1643828400      24070         Benfica
# 1     145988  02.02.2022 21:00:00       1643828400      48881     Bucaramanga
# 2     134785  02.02.2022 21:30:00       1643830200      23423         Smyrnis
# 3     130492  02.02.2022 21:45:00       1643831100      24260          Celtic
# 4     138378  02.02.2022 21:45:00       1643831100      26964        Barnsley
# ...      ...                  ...              ...        ...             ...
# 1128  122387  23.02.2022 02:00:00       1645574400     121917           Sevan
# 1129  122388  23.02.2022 02:00:00       1645574400      18907  Ararat Yerevan
# 1130  122389  23.02.2022 02:00:00       1645574400      18899       Alashkert
# 1131  123016  23.02.2022 02:00:00       1645574400      18901          Urartu
# 1132  133857  23.02.2022 16:00:00       1645624800      18900  Pyunik Yerevan
#
#       team_2_id     team_2_name  country_id country_name  league_id  ...  \
# 0         62198     Gil Vicente       779.0     Portugal        785  ...
# 1         48875       Petrolera      1787.0     Colombia       2213  ...
# 2         23408            PAOK       776.0       Greece        786  ...
# 3         24261         Rangers       782.0     Scotland        783  ...
# 4          6732         Cardiff       291.0      England        428  ...
# ...         ...             ...         ...          ...        ...  ...
# 1128      89920          FC Van       626.0      Armenia        631  ...
# 1129      18906            Noah       626.0      Armenia        631  ...
# 1130      18904  Ararat-Armenia       626.0      Armenia        631  ...
# 1131     121916        Noravank       626.0      Armenia        631  ...
# 1132     121915            BKMA       626.0      Armenia        631  ...
#
#      odds_open_win1  odds_open_draw odds_open_win2  odds_open_tm25  \
# 0             1.248            6.50         13.170           2.520
# 1               NaN             NaN            NaN             NaN
# 2             6.320            3.99          1.558           1.787
# 3             2.150            3.58          3.520           1.917
# 4             2.760            3.24          2.800           1.740
# ...             ...             ...            ...             ...
# 1128            NaN             NaN            NaN             NaN
# 1129            NaN             NaN            NaN             NaN
# 1130            NaN             NaN            NaN             NaN
# 1131            NaN             NaN            NaN             NaN
# 1132            NaN             NaN            NaN             NaN
#
#      odds_open_tb25  odds_close_win1  odds_close_draw  odds_close_win2  \
# 0             1.568            1.483             4.72            6.860
# 1               NaN              NaN              NaN              NaN
# 2             1.980            9.070             4.31            1.411
# 3             1.934            2.340             3.34            3.310
# 4             2.180            3.390             3.33            2.310
# ...             ...              ...              ...              ...
# 1128            NaN              NaN              NaN              NaN
# 1129            NaN              NaN              NaN              NaN
# 1130            NaN              NaN              NaN              NaN
# 1131            NaN              NaN              NaN              NaN
# 1132            NaN              NaN              NaN              NaN
#
#       odds_close_tm25  odds_close_tb25
# 0               2.270            1.684
# 1                 NaN              NaN
# 2               1.671            2.220
# 3               1.917            1.970
# 4               1.719            2.220
# ...               ...              ...
# 1128              NaN              NaN
# 1129              NaN              NaN
# 1130              NaN              NaN
# 1131              NaN              NaN
# 1132              NaN              NaN
#
# [1133 rows x 1397 columns]
